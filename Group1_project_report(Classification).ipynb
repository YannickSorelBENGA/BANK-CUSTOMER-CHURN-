# %% [markdown]
# ## MLDL_PROJECT

# %% [markdown]
# ### Dataset: Bank Customer-Churn-Records
# Data source: https://www.kaggle.com/datasets?search=Bank+Customer-Churn

# %% [markdown]
# ![Pr%C3%A9sentation1.jpg](attachment:Pr%C3%A9sentation1.jpg)

# %% [markdown]
# ### Business Problem<br>
#
# In this project which analyze bank customer churn in three countries (France, Germany and Spain), our objectives will be to understand the factors influencing customer churn,and predict which customers are likely to churn in the future, and propose strategies to mitigate churn.

# %% [markdown]
# ### Methodology

# %% [raw]
# * Data Cleaning and Preprocessing
# * Exploratory Data Analysis (EDA)
# * Feature Engineering
# * Build Predictive Model
# * Model Evaluation
# * Interpretation and Conclusion
# * Business Recommendations

# %% [markdown]
# ### Data Variables

# %% [markdown]
# * **Categorical variables**: Surname, Geography, Gender,Card Type . This variable should be encode in features engineering. We will remove Surname for our analysis.
# * **Numerical variables**: RowNumber, CustomerId, CreditScore, Age, Tenure, Balance, NumOfProducts, HasCrCard,IsActiveMember, EstimatedSalary, Exited, Complain,Satisfaction Score, point Earned. We will remove RowNumber and CustomerId for our analysis

# %% [markdown]
# ## Features explanation
#
# * **Surname**:The family name or last name of an individual.
# * **Geography**:The location or region where the individual is situated.
# * **Gender**:The categorization of an individual as male or female
# * **Card Type**:The type of card associated with a financial or payment system
# * **CustomerId**:A unique identifier assigned to each customer, typically used to distinguish one customer from another
# * **CreditScore**:A numerical representation of an individual's creditworthiness, often used by financial institutions to assess the risk of lending money
# * **Age**:The age of the customer.
# * **Tenure**:he duration or period for which a customer has been associated with a service or organization
# * **Balance**:The amount of money held in an account or available credit.
# * **NumOfProducts**:The number of different products or services the customer is currently using.
# * **HasCrCard**:A binary indicator (yes/no) denoting whether the customer has a credit card
# * **IsActiveMember**:A binary indicator indicating whether the customer is an active member of a service or organization.
# * **EstimatedSalary**: An approximation of the customer's annual salary or income.
# * **Exited**:A binary indicator (yes/no) representing whether the customer has exited or churned from the service
# * **Complain**:A binary indicator (yes/no) indicating whether the customer has filed a complaint.
# * **Satisfaction Score**:A measure of the customer's satisfaction with the service, often obtained through surveys or feedback.
# * **point Earned**:The accumulation of points by the customer, possibly related to a loyalty or rewards program

# %% [markdown]
# ### Dataset

# %% [markdown]
# * We have 18 columns and 10 000 rows

# %% [markdown]
# ### Target variable

# %% [markdown]
# For our analysis, we will use **Complain** as target variable

# %% [markdown]
# ### Predictor

# %% [markdown]
# The other variables will be treated as predictor variables after Features engineering

# %% [markdown]
# ![image%20of%20data%20analysis%20process.png](attachment:image%20of%20data%20analysis%20process.png)

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import researchpy as rp

# %%
df0 = pd.read_csv('Bank Customer-Churn-Records_classification.csv')

# %%
df0.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
df0.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# ...

# %%
df0
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## We have 18 columns and 10 000 rows

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %% [markdown]
# #### Checking the data types

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
# ...

# %% [markdown]
# #### What are the columns?

# %%
df0.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %%
# Checking the shape of the dataset
df0.shape
# Out:
# (10000, 18)

# %%
# find the number of unique values for each column

df0.nunique()
# Out:
# RowNumber             10000
# CustomerId            10000
# Surname                2932
# CreditScore             460
# Geography                 3
# Gender                    2
# Age                      70
# Tenure                   11
# Balance                6382
# NumOfProducts             4
# HasCrCard                 2
# IsActiveMember            2
# EstimatedSalary        9999
# Exited                    2
# Complain                  2
# Satisfaction Score        5
# Card Type                 4
# Point Earned            785
# dtype: int64

# %%
## Checking Variable Exited and Complain

df0.Exited.value_counts()
# Out:
# 0    7962
# 1    2038
# Name: Exited, dtype: int64

# %%
df0.Complain.value_counts()
# Out:
# 0    7956
# 1    2044
# Name: Complain, dtype: int64

# %%
data1 = pd.DataFrame({
    'Exited': [0] * 7962 + [1] * 2038,
    'Complain': [0] * 7956 + [1] * 2044
})

# Calculate the difference
difference = df0['Complain'].value_counts().get(1, 0)- df0['Exited'].value_counts().get(1, 0)

print("Difference between Complain and Exited features:", difference)
# Out:
# Difference between Complain and Exited features: 6

# %% [markdown]
# **The difference between Complain and Exited is to small, then we can drop feature Exited since Complain is the Target**

# %%
# 1. Drop columns which are not required: 'RowNumber'
data_project = df0.drop(columns=['RowNumber','Exited','Surname'], axis=1)

# %%
data_project
# Out:
#       CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0       15634602          619    France  Female   42       2       0.00
# 1       15647311          608     Spain  Female   41       1   83807.86
# 2       15619304          502    France  Female   42       8  159660.80
# 3       15701354          699    France  Female   39       1       0.00
# 4       15737888          850     Spain  Female   43       2  125510.82
# ...          ...          ...       ...     ...  ...     ...        ...
# 9995    15606229          771    France    Male   39       5       0.00
# 9996    15569892          516    France    Male   35      10   57369.61
# 9997    15584532          709    France  Female   36       7       0.00
# 9998    15682355          772   Germany    Male   42       3   75075.31
# 9999    15628319          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Complain  \
# ...

# %%
data_project.shape
# Out:
# (10000, 15)

# %%
data_project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   CreditScore         10000 non-null  int64
#  2   Geography           10000 non-null  object
#  3   Gender              10000 non-null  object
#  4   Age                 10000 non-null  int64
#  5   Tenure              10000 non-null  int64
#  6   Balance             10000 non-null  float64
#  7   NumOfProducts       10000 non-null  int64
#  8   HasCrCard           10000 non-null  int64
#  9   IsActiveMember      10000 non-null  int64
#  10  EstimatedSalary     10000 non-null  float64
#  11  Complain            10000 non-null  int64
#  12  Satisfaction Score  10000 non-null  int64
#  13  Card Type           10000 non-null  object
#  14  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(10), object(3)
# ...

# %%
data_project.describe().T
# Out:
#                       count          mean           std          min  \
# CustomerId          10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore         10000.0  6.505288e+02     96.653299       350.00
# Age                 10000.0  3.892180e+01     10.487806        18.00
# Tenure              10000.0  5.012800e+00      2.892174         0.00
# Balance             10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts       10000.0  1.530200e+00      0.581654         1.00
# HasCrCard           10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember      10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary     10000.0  1.000902e+05  57510.492818        11.58
# Complain            10000.0  2.044000e-01      0.403283         0.00
# Satisfaction Score  10000.0  3.013800e+00      1.405919         1.00
# Point Earned        10000.0  6.065151e+02    225.924839       119.00
#
# ...

# %%
data_project.describe(include='object')
# Out:
#        Geography Gender Card Type
# count      10000  10000     10000
# unique         3      2         4
# top       France   Male   DIAMOND
# freq        5014   5457      2507

# %% [markdown]
# * **Missing Values**

# %%
data_project.isna().sum()
# Out:
# CustomerId            0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# **The dataset don't have missing value**

# %% [markdown]
# * **Duplicates Value**

# %%
data_project.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **There is not duplicated value in the dataset**

# %% [markdown]
# * **Checking Outliers**

# %%
Numeric_cols = ['CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard',
                'IsActiveMember','EstimatedSalary','Complain','Satisfaction Score','Point Earned']

# %%
def out_std(data_project, column,threshold):
    # calculate the mean and standard deviation of the data frame
    data_mean, data_std = data_project[column].mean(), data_project[column].std()
    # calculate the cutoff value
    cut_off = data_std * threshold
    # calculate the lower and upper bound value
    lower, upper = data_mean - cut_off, data_mean + cut_off
    print('The lower bound value is', lower)
    print('The upper bound value is', upper)
    # Calculate the number of records below and above lower and above bound value respectively
    df1 = data_project[data_project[column] > upper]
    df2 = data_project[data_project[column] < lower]
    print('Total number of outliers in column {} are'.format(column), df1.shape[0]+ df2.shape[0])
    plt.figure(figsize = (15,4))
    sns.distplot(data_project[column], kde=False)
    plt.axvspan(xmin = lower,xmax= data_project[column].min(),alpha=0.2, color='red')
    plt.axvspan(xmin = upper,xmax= data_project[column].max(),alpha=0.2, color='red')
    plt.show()
    print("="*100)
    if df1.shape[0]+ df2.shape[0]:
        return True, lower, upper
    else:
        return False, lower, upper

# %%
threshold = 3
columns_outliers={}
for c in Numeric_cols:
    o,l,u= out_std(data_project, c , threshold)
    if o:
        columns_outliers[c]=[l,u]
# Out:
# The lower bound value is 360.56890379160825
# The upper bound value is 940.4886962083918
# Total number of outliers in column CreditScore are 8
# ...
# The lower bound value is 7.458380644886226
# The upper bound value is 70.38521935511378
# Total number of outliers in column Age are 133
# ...
# The lower bound value is -3.6637231311491245
# The upper bound value is 13.689323131149125
# Total number of outliers in column Tenure are 0
# ...
# The lower bound value is -110706.32631915869
# The upper bound value is 263678.10489515867
# Total number of outliers in column Balance are 0
# ...
# The lower bound value is -0.2147630739969808
# The upper bound value is 3.275163073996981
# Total number of outliers in column NumOfProducts are 60
# ...
# The lower bound value is -0.6620213934254271
# The upper bound value is 2.073021393425427
# Total number of outliers in column HasCrCard are 0
# ...
# The lower bound value is -0.9842907853767605
# The upper bound value is 2.0144907853767604
# ...

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# * **Categorical variables**

# %%
# find the level of each categorical variable
data_cat = data_project.select_dtypes(include=['object']).columns

for col in data_cat:
    print(f"Level of {col}:")
    print(data_project[col].value_counts())
    print("*"*50)
# Out:
# Level of Geography:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# **************************************************
# Level of Gender:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# **************************************************
# Level of Card Type:
# DIAMOND     2507
# GOLD        2502
# SILVER      2496
# PLATINUM    2495
# Name: Card Type, dtype: int64
# **************************************************

# %% [markdown]
# ##### Geography

# %%
Geography=data_project['Geography'].value_counts()
# Colors for the pie chart
colors = ['b', 'y', 'g']

# Labels for the pie chart
labels = Geography.index

# Explode each slice slightly
explode = [0.1] * len(Geography)

# Plot the pie chart
plt.figure(figsize=(6, 3))
plt.title('Geography')
plt.pie(Geography, colors=colors, labels=labels, explode=explode,
        counterclock=False, shadow=True, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# * **Insight**: In this campaign analysis, France have the most important customer

# %% [markdown]
# ##### Card Type

# %%
Card_Type=data_project['Card Type'].value_counts()
# Colors for the pie chart
colors = ['b', 'y', 'g','r']

# Labels for the pie chart
labels = Card_Type.index

# Explode each slice slightly
explode = [0.1] * len(Card_Type)

# Plot the pie chart
plt.figure(figsize=(6, 3))
plt.title('Card_Type')
plt.pie(Card_Type, colors=colors, labels=labels, explode=explode,
        counterclock=False, shadow=True, autopct='%1.1f%%')

plt.show()

# %% [markdown]
# **Insight** : The proportion of card detentions is the same for all customers.

# %% [markdown]
# ##### Gender

# %%
gender = data_project['Gender'].value_counts()

# Plot horizontal bar chart
ax = gender.plot(kind='barh', color=['y', 'm'])

# Add values on top of each bar
for i, value in enumerate(gender):
    plt.text(value, i, str(value), ha='left', va='center', fontsize=10)

# Set the title and show the plot
plt.title("Gender", y=0.98, fontdict={"fontsize": 12})  # Adjust title position
plt.show()

# %% [markdown]
# **Insight**: In this dataset, men are the most represented

# %% [markdown]
# #### HasCrCard

# %%
HasCrCard = data_project['HasCrCard'].value_counts()

# Plot horizontal bar chart
ax = HasCrCard.plot(kind='barh', color=['r', 'b'])

# Add values on top of each bar
for i, value in enumerate(gender):
    plt.text(value, i, str(value), ha='left', va='center', fontsize=10)

# Set the title and show the plot
plt.title("HasCrCard", y=0.98, fontdict={"fontsize": 12})  # Adjust title position
plt.show()

# %% [markdown]
# **Insight**: Most customer have credit card

# %%
IsActiveMember = data_project['IsActiveMember'].value_counts()

# Plot horizontal bar chart
ax = IsActiveMember.plot(kind='barh', color=['r', 'y'])

# Add values on top of each bar
for i, value in enumerate(gender):
    plt.text(value, i, str(value), ha='left', va='center', fontsize=10)

# Set the title and show the plot
plt.title("IsactiveMember", y=0.98, fontdict={"fontsize": 12})  # Adjust title position
plt.show()

# %% [markdown]
# **Insight**: Most customer are active

# %% [markdown]
# ### Numerical Variables

# %%
Numeric_cols = data_project.select_dtypes(include=['int64','float64']).columns
Numeric_cols
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Complain', 'Satisfaction Score', 'Point Earned'],
#       dtype='object')

# %% [markdown]
# ### Visualization of Numerical variable

# %%
plt.figure(figsize=(20, 15))
Numeric_cols = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary', 'Satisfaction Score', 'Point Earned']
for i, feature in enumerate(Numeric_cols, 1):
    plt.subplot(2, 4, i)
    sns.histplot(data_project[feature], bins=30, kde=True)
    plt.title(f'Distribution of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bavariate Analysis

# %% [markdown]
# ### Categorical vs. Categorical

# %% [markdown]
# ### Chi-squared test of independence
#
# - H0: There is no statistically significant relationship between 'geography' and 'Gender'.
#
# - Ha:There is a statistically significant relationship between 'geography' and 'Gender'.

# %%
from scipy.stats import chi2_contingency
def chi_square(c1,c2):
    chi_2, p_val, dof, exp_val = chi2_contingency(pd.crosstab(data_project[c1],data_project[c2],margins = False))# make sure margins = False
    print("Actual values:\n")
    print(pd.crosstab(data_project[c1],data_project[c2],margins = False))
    print("_"*100)
    print("Expected values: \n")
    print(exp_val)
    print("_"*100)
    #print('\nChi-square is : %f'%chi_2, '\n\np_value is : %f'%p_val, '\n\ndegree of freedom is : %i'%dof)
    print(f'\nChi-square is : {chi_2}', f'\n\np_value is : {p_val}', f'\n\ndegree of freedom is :{dof}')
    print("_"*100)
    if exp_val.min()<5 or np.sum(exp_val)<50 : print("\n********************************************\nWarning :We have some small expected \
values or the total number of observations is not enough to get any conclusion\n******************************************** ")
        #Note for sum of all values in dataframe use df.values.sum() and for numpy.ndarray use np.sum(arr)
    elif p_val < 0.05:# consider significan level is 5%
        print(F"\nThere is statistically significant correlation between {c1} and {c2} at 0.05 significant level")
    else:
        print(F"\nThere is no correlation between the two variables( we don't have enough evidence to conclude there is a a statistically significant relationship between {c1} and {c2}")

# %% [markdown]
# ##### Chi-squared test of independence Geography vs Gender

# %%
chi_square('Geography' , 'Gender')
# Out:
# Actual values:
#
# Gender     Female  Male
# Geography
# France       2261  2753
# Germany      1193  1316
# Spain        1089  1388
# ____________________________________________________________________________________________________
# Expected values:
#
# [[2277.8602 2736.1398]
#  [1139.8387 1369.1613]
#  [1125.3011 1351.6989]]
# ____________________________________________________________________________________________________
#
# Chi-square is : 6.918159617700976
#
# p_value is : 0.03145869671789379
#
# degree of freedom is :2
# ____________________________________________________________________________________________________
#
# There is statistically significant correlation between Geography and Gender at 0.05 significant level

# %% [markdown]
# #### Chi-squared test of independence Geography vs Card Type

# %%
chi_square('Geography' , 'Card Type')
# Out:
# Actual values:
#
# Card Type  DIAMOND  GOLD  PLATINUM  SILVER
# Geography
# France        1230  1235      1264    1285
# Germany        648   653       608     600
# Spain          629   614       623     611
# ____________________________________________________________________________________________________
# Expected values:
#
# [[1257.0098 1254.5028 1250.993  1251.4944]
#  [ 629.0063  627.7518  625.9955  626.2464]
#  [ 620.9839  619.7454  618.0115  618.2592]]
# ____________________________________________________________________________________________________
#
# Chi-square is : 5.404414860242146
#
# p_value is : 0.4930839047769696
#
# degree of freedom is :6
# ____________________________________________________________________________________________________
#
# There is no correlation between the two variables( we don't have enough evidence to conclude there is a a statistically significant relationship between Geography and Card Type

# %% [markdown]
# #### Chi-squared test of independence Gender vs Card Type

# %%
chi_square('Gender' , 'Card Type')
# Out:
# Actual values:
#
# Card Type  DIAMOND  GOLD  PLATINUM  SILVER
# Gender
# Female        1163  1062      1162    1156
# Male          1344  1440      1333    1340
# ____________________________________________________________________________________________________
# Expected values:
#
# [[1138.9301 1136.6586 1133.4785 1133.9328]
#  [1368.0699 1365.3414 1361.5215 1362.0672]]
# ____________________________________________________________________________________________________
#
# Chi-square is : 12.02048469245887
#
# p_value is : 0.007313317007741218
#
# degree of freedom is :3
# ____________________________________________________________________________________________________
#
# There is statistically significant correlation between Gender and Card Type at 0.05 significant level

# %% [markdown]
# ### Visualization of Categorical vs. Categorical variables

# %%
# Count the occurrences of each combination of Geography and Gender
count_geo_gen = data_project.groupby(['Geography', 'Gender']).size().unstack()

# Plotting the stacked bar chart
count_geo_gen.plot(kind='barh', stacked=True)
plt.ylabel('Geography')
plt.xlabel('Count')
plt.title('Stacked Bar Chart for Geography and Gender')
plt.show()

# %% [markdown]
# **Insight**: France have the most customer (Male and Female)

# %%
Geo_Card_type = data_project.groupby(['Geography', 'Card Type']).size().unstack()

Geo_Card_type.plot(kind='barh', stacked=True)
plt.ylabel('Geography')
plt.xlabel('Count')
plt.title('Stacked Bar Chart for Geography and Card Type')
plt.show()

# %%
gender_Card_type = data_project.groupby(['Card Type', 'Gender']).size().unstack()

gender_Card_type.plot(kind='bar', stacked=True)
plt.ylabel('Card Type')
plt.xlabel('Count')
plt.title('Stacked Bar Chart for Card Type and Gender')
plt.show()

# %%
gender_HasCrCard = data_project.groupby(['HasCrCard', 'Gender']).size().unstack()

gender_HasCrCard.plot(kind='bar', stacked=True)
plt.ylabel('Count')
plt.xlabel('HasCrCard')
plt.title('Stacked Bar Chart for HasCrCard and Gender')
plt.show()

# %%
gender_IsActiveMember = data_project.groupby(['IsActiveMember', 'Gender']).size().unstack()

gender_IsActiveMember.plot(kind='bar', stacked=True)
plt.ylabel('Count')
plt.xlabel('IsActiveMember')
plt.title('Stacked Bar Chart for IsActiveMember and Gender')
plt.show()

# %% [markdown]
# ### Numerical  vs Numerical Variables

# %%
data_project.corr()
# Out:
#                     CustomerId  CreditScore       Age    Tenure   Balance  \
# CustomerId            1.000000     0.005308  0.009497 -0.014883 -0.012419
# CreditScore           0.005308     1.000000 -0.003965  0.000842  0.006268
# Age                   0.009497    -0.003965  1.000000 -0.009997  0.028308
# Tenure               -0.014883     0.000842 -0.009997  1.000000 -0.012254
# Balance              -0.012419     0.006268  0.028308 -0.012254  1.000000
# NumOfProducts         0.016972     0.012238 -0.030680  0.013444 -0.304180
# HasCrCard            -0.014025    -0.005458 -0.011721  0.022583 -0.014858
# IsActiveMember        0.001665     0.025651  0.085472 -0.028362 -0.010084
# EstimatedSalary       0.015271    -0.001384 -0.007201  0.007784  0.012797
# Complain             -0.007293    -0.027048  0.283530 -0.013047  0.119124
# Satisfaction Score   -0.000865    -0.012599 -0.000876  0.008663 -0.002588
# Point Earned         -0.013076     0.000077  0.002222 -0.010196  0.014608
#
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(data_project.corr(), cbar=True, annot=True,cmap="YlGnBu", square=True, fmt='.3f', annot_kws={'size': 7})
plt.title("Correlation between variables")
# Out:
# Text(0.5, 1.0, 'Correlation between variables')

# %% [markdown]
# **There is not high correlation between numerical variable**

# %% [markdown]
# ### Categorical vs. Numerical

# %% [markdown]
# ## Target: COMPLAIN

# %%
data_project.Complain.value_counts()
# Out:
# 0    7956
# 1    2044
# Name: Complain, dtype: int64

# %% [markdown]
# ## We have an imbalanced, accuracy may not be the right metric of data with class imbalance

# %%
sns.histplot(data_project["Complain"], kde=False, color="skyblue")
plt.show()

# %% [markdown]
# ### Gender vs. Complain

# %%
sns.catplot(x="Gender", kind="count",hue = 'Complain', palette='BuPu', data=data_project)
plt.title("Gender Vs. Complain", y=1, fontdict={"fontsize": 10})
plt.show()

# %% [markdown]
# **Insight** : Female are the ones who complain the most

# %% [markdown]
# ### Geography vs. Complain

# %%
sns.catplot(x="Geography", kind="count",hue = 'Complain', palette='hls', data=data_project)
plt.title("Geography Vs. Complain", y=1, fontdict={"fontsize": 10})
plt.show()

# %% [markdown]
# **Insight**: France and Germany are the countries with the most complain customer

# %% [markdown]
# ### Card Type vs. Complain

# %%
sns.catplot(x="Card Type", kind="count",hue = 'Complain', palette='Paired', data=data_project)
plt.title("Card Type Vs. Complain", y=1, fontdict={"fontsize": 10})
plt.show()

# %% [markdown]
# **Insight**: Customer with the most diamond cards are the ones who complain the most

# %% [markdown]
# ### HasCrCard vs. Complain

# %%
sns.catplot(x="HasCrCard", kind="count",hue = 'Complain', palette='viridis', data=data_project)
plt.title("HasCrCard Vs. Complain", y=1, fontdict={"fontsize": 10})
plt.show()

# %% [markdown]
# ### IsActiveMember Vs. Complain

# %%
sns.catplot(x="IsActiveMember", kind="count",hue = 'Complain', palette='husl', data=data_project)
plt.title("IsActiveMember Vs. Complain", y=1, fontdict={"fontsize": 10})
plt.show()

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Encoding Categorical Variables

# %%
# split first before did encoding
# One-hot encoding for the Categorical columns

data_encoded1 = pd.get_dummies(data_project, columns=['Geography', 'Gender', 'Card Type'], drop_first=True)

# %%
# Display the first 10 rows

data_encoded1.head(5)
# Out:
#    CustomerId  CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0    15634602          619   42       2       0.00              1          1
# 1    15647311          608   41       1   83807.86              1          0
# 2    15619304          502   42       8  159660.80              3          1
# 3    15701354          699   39       1       0.00              2          0
# 4    15737888          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Complain  Satisfaction Score  \
# 0               1        101348.88         1                   2
# 1               1        112542.58         1                   3
# 2               0        113931.57         1                   3
# 3               0         93826.63         0                   5
# 4               1         79084.10         0                   5
#
#    Point Earned  Geography_Germany  Geography_Spain  Gender_Male  \
# ...

# %%
data_project.shape, data_encoded1.shape
# Out:
# ((10000, 15), (10000, 18))

# %%
len(data_encoded1.columns)
# Out:
# 18

# %%
data_encoded1.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Complain', 'Satisfaction Score', 'Point Earned', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male', 'Card Type_GOLD',
#        'Card Type_PLATINUM', 'Card Type_SILVER'],
#       dtype='object')

# %%
## Define Target and Predictor

X = data_encoded1.drop(['Complain'], axis=1)
y = data_encoded1['Complain']

# %%
X.shape, y.shape
# Out:
# ((10000, 17), (10000,))

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   CreditScore         10000 non-null  int64
#  2   Age                 10000 non-null  int64
#  3   Tenure              10000 non-null  int64
#  4   Balance             10000 non-null  float64
#  5   NumOfProducts       10000 non-null  int64
#  6   HasCrCard           10000 non-null  int64
#  7   IsActiveMember      10000 non-null  int64
#  8   EstimatedSalary     10000 non-null  float64
#  9   Satisfaction Score  10000 non-null  int64
#  10  Point Earned        10000 non-null  int64
#  11  Geography_Germany   10000 non-null  uint8
#  12  Geography_Spain     10000 non-null  uint8
#  13  Gender_Male         10000 non-null  uint8
#  14  Card Type_GOLD      10000 non-null  uint8
#  15  Card Type_PLATINUM  10000 non-null  uint8
# ...

# %% [markdown]
# ### Splitting test and training sets for modeling

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y,test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 17), (2000, 17), (8000,), (2000,))

# %%
y_train.value_counts()
# Out:
# 0    6360
# 1    1640
# Name: Complain, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    1596
# 1     404
# Name: Complain, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 7389 to 2732
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          8000 non-null   int64
#  1   CreditScore         8000 non-null   int64
#  2   Age                 8000 non-null   int64
#  3   Tenure              8000 non-null   int64
#  4   Balance             8000 non-null   float64
#  5   NumOfProducts       8000 non-null   int64
#  6   HasCrCard           8000 non-null   int64
#  7   IsActiveMember      8000 non-null   int64
#  8   EstimatedSalary     8000 non-null   float64
#  9   Satisfaction Score  8000 non-null   int64
#  10  Point Earned        8000 non-null   int64
#  11  Geography_Germany   8000 non-null   uint8
#  12  Geography_Spain     8000 non-null   uint8
#  13  Gender_Male         8000 non-null   uint8
#  14  Card Type_GOLD      8000 non-null   uint8
# ...

# %%
X_train.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Satisfaction Score', 'Point Earned', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male', 'Card Type_GOLD',
#        'Card Type_PLATINUM', 'Card Type_SILVER'],
#       dtype='object')

# %%
X_columns = ['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
       'Satisfaction Score', 'Point Earned', 'Geography_Germany',
       'Geography_Spain', 'Gender_Male', 'Card Type_GOLD',
       'Card Type_PLATINUM', 'Card Type_SILVER']

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_train)

# %%
X_train.columns=list(X_columns)
X_test.columns=list(X_columns)

# %%
X_train
# Out:
#       CustomerId  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# 0      -0.202167     0.169582 -0.464608  0.006661 -1.215717       0.809503
# 1       0.807044    -2.304559  0.301026 -1.377440 -0.006312      -0.921591
# 2      -1.519081    -1.191196 -0.943129 -1.031415  0.579935      -0.921591
# 3       1.241115     0.035566  0.109617  0.006661  0.473128      -0.921591
# 4      -1.110869     2.056114  1.736588  1.044737  0.810193       0.809503
# ...          ...          ...       ...       ...       ...            ...
# 7995   -1.485104    -0.582970 -0.656016 -0.339364  0.703104       0.809503
# 7996   -0.617785     1.478815 -1.613058 -0.339364  0.613060      -0.921591
# 7997   -1.632338     0.901515 -0.368904  0.006661  1.361474       0.809503
# 7998   -0.381732    -0.624205 -0.081791  1.390762 -1.215717       0.809503
# 7999   -1.375084    -0.284011  0.875251 -1.377440  0.511364      -0.921591
#
# ...

# %%
X_train.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure       Balance  \
# count  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03
# mean   1.143219e-14  4.707346e-16  1.261213e-16  1.421085e-16  1.270095e-16
# std    1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00
# min   -1.753280e+00 -3.098346e+00 -1.995875e+00 -1.723466e+00 -1.215717e+00
# 25%   -8.683616e-01 -6.963677e-01 -6.560163e-01 -1.031415e+00 -1.215717e+00
# 50%    5.809568e-03  1.494794e-02 -1.774954e-01  6.660988e-03  3.322869e-01
# 75%    8.639896e-01  6.953368e-01  4.924340e-01  6.987116e-01  8.224106e-01
# max    1.733112e+00  2.056114e+00  4.703418e+00  1.736788e+00  2.593763e+00
#
#        NumOfProducts     HasCrCard  IsActiveMember  EstimatedSalary  \
# count   8.000000e+03  8.000000e+03    8.000000e+03     8.000000e+03
# mean   -5.773160e-17  6.883383e-17    5.506706e-17    -3.996803e-17
# std     1.000063e+00  1.000063e+00    1.000063e+00     1.000063e+00
# ...

# %%
X_test.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure       Balance  \
# count  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03  8.000000e+03
# mean   1.143219e-14  4.707346e-16  1.261213e-16  1.421085e-16  1.270095e-16
# std    1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00  1.000063e+00
# min   -1.753280e+00 -3.098346e+00 -1.995875e+00 -1.723466e+00 -1.215717e+00
# 25%   -8.683616e-01 -6.963677e-01 -6.560163e-01 -1.031415e+00 -1.215717e+00
# 50%    5.809568e-03  1.494794e-02 -1.774954e-01  6.660988e-03  3.322869e-01
# 75%    8.639896e-01  6.953368e-01  4.924340e-01  6.987116e-01  8.224106e-01
# max    1.733112e+00  2.056114e+00  4.703418e+00  1.736788e+00  2.593763e+00
#
#        NumOfProducts     HasCrCard  IsActiveMember  EstimatedSalary  \
# count   8.000000e+03  8.000000e+03    8.000000e+03     8.000000e+03
# mean   -5.773160e-17  6.883383e-17    5.506706e-17    -3.996803e-17
# std     1.000063e+00  1.000063e+00    1.000063e+00     1.000063e+00
# ...

# %% [markdown]
# ## Feature selection by using VIF

# %%
# Check for the VIF values of the feature variables. 
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
col = ['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
       'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
       'Satisfaction Score', 'Point Earned', 'Geography_Germany',
       'Geography_Spain', 'Gender_Male', 'Card Type_GOLD',
       'Card Type_PLATINUM', 'Card Type_SILVER']

# %%
col
# Out:
# ['CustomerId',
#  'CreditScore',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary',
#  'Satisfaction Score',
#  'Point Earned',
#  'Geography_Germany',
#  'Geography_Spain',
#  'Gender_Male',
#  'Card Type_GOLD',
#  'Card Type_PLATINUM',
#  'Card Type_SILVER']

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_train)

# %%
X_train.columns=list(col)
X_test.columns=list(col)

# %%
len(X_train.columns)
# Out:
# 17

# %%
X_train.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Satisfaction Score', 'Point Earned', 'Geography_Germany',
#        'Geography_Spain', 'Gender_Male', 'Card Type_GOLD',
#        'Card Type_PLATINUM', 'Card Type_SILVER'],
#       dtype='object')

# %% [markdown]
# **Let's check if all feature  have a high VIF**

# %%
vif = pd.DataFrame()
vif['Features'] = X_train[col].columns
vif['VIF'] = [variance_inflation_factor(X_train[col].values, i) for i in range(X_train[col].shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#               Features   VIF
# 16    Card Type_SILVER  1.52
# 15  Card Type_PLATINUM  1.52
# 14      Card Type_GOLD  1.51
# 4              Balance  1.35
# 11   Geography_Germany  1.34
# 5        NumOfProducts  1.13
# 12     Geography_Spain  1.12
# 2                  Age  1.01
# 7       IsActiveMember  1.01
# 13         Gender_Male  1.00
# 0           CustomerId  1.00
# 10        Point Earned  1.00
# 9   Satisfaction Score  1.00
# 1          CreditScore  1.00
# 6            HasCrCard  1.00
# 3               Tenure  1.00
# 8      EstimatedSalary  1.00

# %% [markdown]
# **There is not multicolinearity by the feature. Then we will use all the feature**

# %% [markdown]
# ## Modeling

# %% [markdown]
# The problem can be identified as Binary classification whether the customer will Complain or not(0-1)

# %% [markdown]
# Since we have an imbalanced dataset, accuracy can give us false assumptions regarding the classifier’s performance, it’s better to rely on precision and recall. Precision and recall can be combined into a single score that seeks to balance both concerns, called the F-score or the F-measure. In this project,we will select the best model based on F-score.

# %% [markdown]
# We will use this Machine Algorithm model and choose the model with the best model.
#
# * **Logistic Regression**
# * **Decision Tree**
# * **Random_Forest**<br><br>
# Also We will apply Hyperparameter Tuning based on F-score with **Grid Search** , then based on F1_score we will select the best model.

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, classification_report,f1_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve, average_precision_score

# %% [markdown]
# **We will create infrastructure for the rest of the code for different machine learning Algorithm**<br>
# name: name of the model<br>
# y_train: true value of y<br>
# X_train: features<br>
# model: model to be fit<br>
# folds:number of folds in cv<br>
# norm:L1 or L2<br>
# C: inverse of regularization strenght(must be a positive float)<br>
# class_weight: weight associated with classes

# %%
pip install --upgrade scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
## Create an entry to store the data

def store_results(name, X_train,y_train,X_test,y_test,model,folds, norm, c, Class_weght='N/A'):
    #train the model
    model.fit(X_train,y_train)
    
    #predict on the data test dataset
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    # Evaluation of the model
    
    train_accuracy_score = accuracy_score(y_train,y_pred_train)
    test_accuracy_score = accuracy_score(y_test, y_pred)
    train_f1_score = round(metrics.f1_score(y_train,y_pred_train),2)
    test_f1_score = round(metrics.f1_score(y_test, y_pred),2)
    classificationReport = classification_report(y_test, y_pred)
    print('classification_report:\n',classificationReport)
    print('*'*60)
    
    ## Compute and plot the confusion matrix
    
    confusionMatrix = confusion_matrix(y_test, y_pred)
    categories = ['Negative','Positive']
    group_names = ['TN','FP','FN','TP']
    group_percentages = ['{0:.2%}'.format(value) for value in confusionMatrix.flatten()/np.sum(confusionMatrix)]
    labels = [f'{v1}: {v2}\n\n{v3}' for v1, v2, v3 in zip(group_names,confusionMatrix.flatten(),group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(confusionMatrix, annot=labels, cmap='Blues', fmt = '',
    xticklabels = categories, yticklabels = categories)
    plt.xlabel('predicted values', fontdict = {'size':14}, labelpad = 10)
    plt.ylabel('Actual values', fontdict = {'size':14}, labelpad = 10)
    plt.title('confusion Matrix', fontdict = {'size':18}, pad = 20)
    plt.show()
    print('_'*60)
    
    print('train f1 score:\n')
    print(round(metrics.f1_score(y_train,y_pred_train),2))
    print('_'*60)
    
    print('test f1 score:\n')
    print(round(metrics.f1_score(y_test, y_pred),2))
    print('_'*60)
    #metrics.plot_roc_curve(model, X_test, y_test)
    
     # Compute ROC curve
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    
    # Compute Precision-Recall curve
    precision, recall, _ = precision_recall_curve(y_test, model.predict_proba(X_test)[:, 1])
    
    # Plot ROC curve
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC-curve')
    plt.xlabel('False Positive Rate(Positive Label)')
    plt.ylabel('True Positive Rate(Positive Label)')
    plt.legend(loc='lower right')
    plt.show()
    
    # Plot Precision-Recall curve
    plt.figure(figsize=(8, 4))
    plt.step(recall, precision, color='b', where='post', label=f'Precision-Recall curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve')
    plt.legend()
    plt.show()
    
    
    # cross validation scores for the model
    
    auc = cross_val_score(model, X_train, y_train, cv=folds, n_jobs=-1, scoring = 'roc_auc').mean()
    Accuracy = cross_val_score(model, X_train, y_train, cv=folds, n_jobs=-1).mean()
    scores = cross_val_score(model, X_train, y_train, cv=folds, n_jobs=-1, scoring='f1')
    f1score = scores.mean()
    
    entry = {'Model': [name],
            'Regularization': [norm],
            'C': [c],
            'Class_Weight': [Class_weght],
            'AUC': [auc],
            'train_accuracy_score': [train_accuracy_score],
            'test_accuracy_score': [test_accuracy_score],
            'train_f1_score': [train_f1_score],
            'test_f1_score': [test_f1_score],
            'CrossVal_mean(Accuracy)': [Accuracy],
            'CrossVal_mean(F1_score)': [f1score],
            'Crossval1(f1)': [scores[0]],
            'Crossval1(f1)': [scores[1]],
            'Crossval1(f1)': [scores[2]],
            'Crossval1(f1)': [scores[3]],
            }
    result = pd.DataFrame(entry)
    return result

# %% [markdown]
# ## Logistic Regression
#
# * With L2 regularization (Ridge)

# %%
LR = LogisticRegression(solver = 'liblinear' , random_state=0)

# %%
outcome = store_results('Logistic Regression', X_train, y_train, X_test, y_test, LR, 5, 'L2', 1)
outcome
Model_Comparison = outcome.copy()
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1596
#            1       0.60      0.25      0.35       404
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.60      0.62      2000
# weighted avg       0.79      0.81      0.78      2000
#
# ************************************************************
# ____________________________________________________________
# train f1 score:
#
# 0.31
# ____________________________________________________________
# test f1 score:
#
# 0.35
# ____________________________________________________________

# %% [markdown]
# As we can see since this data is imbalaced data, the algorithm find the best acuracy when it predicted 0 for most of the records and means this model is not able to distingueshed between positive and negative class

# %% [markdown]
# **Our model has 81% overall accuracy, but is it because it's predicting more the majority class. we can see f1_score for positive class (class 1.0) is equal to 0.35**

# %% [markdown]
# ### Since we have imbalanced classes, we will handle  this Imbalanced

# %% [markdown]
# ## """Handle imbalanced classes"""

# %%
LR_withBalance = LogisticRegression(solver ='liblinear', class_weight ='balanced', random_state=0)

# %%
outcome1 = store_results('Logisitc Regression', X_train,y_train,X_test,y_test,LR_withBalance,5,'L2',1,'Balanced')
Model_Comparison1 = Model_Comparison.append(outcome1)
Model_Comparison1
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79      1596
#            1       0.38      0.73      0.50       404
#
#     accuracy                           0.70      2000
#    macro avg       0.64      0.71      0.64      2000
# weighted avg       0.80      0.70      0.73      2000
#
# ************************************************************
# ____________________________________________________________
# train f1 score:
#
# 0.49
# ____________________________________________________________
# test f1 score:
#
# 0.5
# ____________________________________________________________
#                  Model Regularization  C Class_Weight       AUC  \
# 0  Logistic Regression             L2  1          N/A  0.761284
# 0  Logisitc Regression             L2  1     Balanced  0.764763
#
#    train_accuracy_score  test_accuracy_score  train_f1_score  test_f1_score  \
# ...

# %% [markdown]
# ## Decision Tree (with Hyperparameter Tuning with Grid Search )

# %% [markdown]
# We will use the original dataset since Decision tree in not sensitive to outliers, missing value and imbalance data

# %%
X_DT = data_encoded1.drop(['Complain'], axis=1)
y_DT = data_encoded1['Complain']

# %%
## splitting test and training dataset

X_train1,X_test1, y_train1, y_test1 = train_test_split(X_DT,y_DT,test_size=0.2, random_state=0)

# %%
X_train1.shape, X_test1.shape, y_train1.shape, y_test1.shape
# Out:
# ((8000, 17), (2000, 17), (8000,), (2000,))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT =DecisionTreeClassifier(class_weight='balanced',random_state=0)
param= {'criterion':['gini','entropy'],'max_depth':range(3,12),'min_samples_split':[3,4,5,6],'min_samples_leaf':[2,3,4]}
model=GridSearchCV(DT,param,cv=5,scoring='f1')
model.fit(X_train1,y_train1)
model.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 8,
#  'min_samples_leaf': 4,
#  'min_samples_split': 3}

# %%
DT=model.best_estimator_
output = store_results("Tuned Decision Tree",X_train1, y_train1,X_test1, y_test1, DT, 5,"N/A", 1,"Balanced")
Model_Comparison2 = Model_Comparison1.append (output)
Model_Comparison2
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.74      0.83      1596
#            1       0.44      0.79      0.56       404
#
#     accuracy                           0.75      2000
#    macro avg       0.69      0.77      0.70      2000
# weighted avg       0.83      0.75      0.77      2000
#
# ************************************************************
# ____________________________________________________________
# train f1 score:
#
# 0.62
# ____________________________________________________________
# test f1 score:
#
# 0.56
# ____________________________________________________________
#                  Model Regularization  C Class_Weight       AUC  \
# 0  Logistic Regression             L2  1          N/A  0.761284
# 0  Logisitc Regression             L2  1     Balanced  0.764763
# 0  Tuned Decision Tree            N/A  1     Balanced  0.821710
#
# ...

# %% [markdown]
# ## Random Forest

# %% [markdown]
# ## Tuning

# %% [markdown]
# ## For class_weight='balanced'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
param_grid={'n_estimators':range(10,110,10),'max_depth':[1,2,3,5,7,8,9],
            'min_samples_split':[3,5],'criterion':['gini','entropy']}

# %%
RF=GridSearchCV(RandomForestClassifier(class_weight='balanced',random_state=0),param_grid,cv=5,scoring='f1')
RF.fit(X_train, y_train)
RF.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 9,
#  'min_samples_split': 3,
#  'n_estimators': 70}

# %%
RF_tuned=RF.best_estimator_
output = store_results("Tuned Random Forests",X_train, y_train,X_test, y_test, RF_tuned, 5,"N/A",
                       1,"Balanced")
Model_Comparison3 = Model_Comparison2.append (output)
Model_Comparison3
# Out:
# classification_report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89      1596
#            1       0.56      0.71      0.62       404
#
#     accuracy                           0.83      2000
#    macro avg       0.74      0.78      0.76      2000
# weighted avg       0.85      0.83      0.84      2000
#
# ************************************************************
# ____________________________________________________________
# train f1 score:
#
# 0.74
# ____________________________________________________________
# test f1 score:
#
# 0.62
# ____________________________________________________________
#                   Model Regularization  C Class_Weight       AUC  \
# 0   Logistic Regression             L2  1          N/A  0.761284
# 0   Logisitc Regression             L2  1     Balanced  0.764763
# 0   Tuned Decision Tree            N/A  1     Balanced  0.821710
# ...

# %% [markdown]
# ### Model Comparison

# %%
Model_Comparison3.sort_values(by="AUC", ascending=False)
# Out:
#                   Model Regularization  C Class_Weight       AUC  \
# 0  Tuned Random Forests            N/A  1     Balanced  0.856168
# 0   Tuned Decision Tree            N/A  1     Balanced  0.821710
# 0   Logisitc Regression             L2  1     Balanced  0.764763
# 0   Logistic Regression             L2  1          N/A  0.761284
#
#    train_accuracy_score  test_accuracy_score  train_f1_score  test_f1_score  \
# 0              0.884250                0.828            0.74           0.62
# 0              0.792500                0.753            0.62           0.56
# 0              0.710875                0.703            0.49           0.50
# 0              0.808000                0.814            0.31           0.35
#
#    CrossVal_mean(Accuracy)  CrossVal_mean(F1_score)  Crossval1(f1)
# 0                 0.838500                 0.622252       0.604380
# 0                 0.784750                 0.583071       0.596908
# ...

# %% [markdown]
# ## Interpretation and conclusion

# %% [markdown]
# ### Factors to Consider

# %% [markdown]
# 1. **AUC (Area Under the ROC Curve)**: This represents the model's ability to distinguish between the classes.
# 2. **Accuracy**: This metric checks the percentage of correct predictions.
# 3. **F1 Score**: The F1 Score is the harmonic mean of Precision and Recall.
# 4. **Class Weighting**: Important for imbalanced datasets.
# 5. **Cross-Validation F1 Score**: Ensures the model is not overfitting

# %% [markdown]
# ### Model Evaluation for Complain through rate (Bank_Customer_churn)prediction

# %% [markdown]
# Predicting the rate of customer churn at a bank is essentially a classification problem that aims to predict whether or not a complaining customer will leave the bank. The selection of an optimal model must be guided by several criteria, including performance measures and specific objectives related to the problem in question.  Below is a detailed analysis based on the measures provided:

# %% [markdown]
# ### 1. **AUC (Area Under the ROC Curve)**:

# %% [markdown]
# AUC provides an aggregate measure of model performance over all potential classification thresholds. A higher AUC is preferable as it indicates the model's capability to differentiate between the positive and negative classes.

# %% [markdown]
# ### 2. **Accuracy**:
# Accuracy quantifies the fraction of correct predictions out of all the predictions made. However, it's crucial to note that accuracy might not always be the ideal metric, especially in scenarios with imbalanced datasets.
#
# ### 3. **F1 Score**:
# The F1 Score is a balanced mean of precision and recall, thereby providing a harmonized perspective on the model's performance. This is especially useful in contexts where the dataset is imbalanced.
#
# From the given table:
#
# - The AUC score remains relatively consistent across the majority of the models, ranging around 0.76-0.856. It indicates a certain level of stability and reliability in the model performances.
#
# - The model **Tuned Random Forests** with the 'Balanced' class weight achieves the highest test F1 score, registering at 0.62. It indicates that the model is capturing a good portion of the actual churn cases (recall), while also minimizing the number of false positive predictions (precision). Other variations of decision trees and Logistic regression with either balanced and imbalanced class weights are between 0.35 and 0.56.
#
#
# **Conclusion**:
#
# - The **Tuned Random Forests** model with a 'Balanced' class weight emerges as a strong contender due to its leading F1 score **(0.62)**. it's suggests a reasonably good balance between precision and recall for random forest model in predicting bank customer churn.

# %% [markdown]
# ### Business Recommandation

# %% [markdown]
# * **Proactive Customer Engagement**: Implement proactive communication startegies for customers identified as high-risk for churn. Adress their concerns promptly and provide personalized solutions to enchance their experience<br>
#
# * **Improve Complaint Handling Processes**: Evaluate and potentially enhance your complaint handling processes. Addressing customer complaints effectively can significantly impact customer satisfaction and loyalty<br>
#
# * **Enhance Customer Support**: Invest in improving customer support services. This could include training customer service representatives to handle complaints more effectively and efficiently<br>
#
# * **Monitor Customer Satisfaction Metrics**: Implement ongoing monitoring of customer satisfaction metrics. Regularly assess the impact of your initiatives on customer satisfaction and adjust your strategies accordingly<br>
#
# * **Benchmarking Against Competitors**:Compare  customer churn rates and satisfaction scores with industry benchmarks. Identify areas where the bank can outperform competitors and focus on those aspects.
#
# * **Communication Strategy**: Develop a clear communication strategy to keep customers informed about improvements, updates, or changes in services. Transparent communication can build trust and reduce the likelihood of churn.<br>

# %% [markdown]
# ## Submitted by

# %% [markdown]
# **Group Members**
#   * **Yannick Sorel BENGA BENGUA**
#   * **MELAKU Tessema**
#   * **Frank ZHAO**

# %% [markdown]
# # THANK YOU
